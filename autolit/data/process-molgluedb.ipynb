# %%
import pandas as pd
import requests
from Bio import Entrez
import dotenv

Entrez.email = Entrez.email = dotenv.get_key("../.env", "NCBI_EMAIL")

# %%
df = pd.read_csv("raw/exported-molgluedb.csv")
df['DOI'] = df['SourceAddress_Website'].apply(lambda x : x[len("https://doi.org/"):])
df.head()
df.drop("SourceAddress_Website", axis=1, inplace=True)
df.head()
# df.to_csv("ground_truth.csv")
# Out:
#    DATAID                                             SMILES         Name  \
# 0       1  [2H]C([2H])([2H])OC1=CC=C2C=C(C(=O)NC3=CC=C4C(...           36
# 1      90  CC(C)(C)CC(C)(C)NC1=C(C2=CC=C3C(=O)N(C4CCC(=O)...  Compound 12
# 2      91  CC(C)(C)CC(C)(C)NC1=C(C2=CC=C3C(=O)N(C4CCC(=O)...  Compound 11
# 3      98  CC(C)(C)NC1=C(C2=CC=C3C(=O)N(C4CCC(=O)NC4=O)C(...   Compound 4
# 4      99  CC(C)(C)NC1=C(C2=CC=C3C(=O)N(C4CCC(=O)NC4=O)CC...   Compound 1
#
#                                                IUPAC  \
# 0  N-[2-(2,6-dioxopiperidin-3-yl)-1-oxo-3H-isoind...
# 1  2-(2,6-dioxopiperidin-3-yl)-5-[3-(2,4,4-trimet...
# 2  3-[3-oxo-6-[3-(2,4,4-trimethylpentan-2-ylamino...
# 3  5-[3-(tert-butylamino)imidazo[1,2-a]pyridin-2-...
# 4  3-[6-[3-(tert-butylamino)imidazo[1,2-a]pyridin...
#
#                                             StdInChl  \
# 0  InChI=1S/C25H21N3O5/c1-33-19-6-4-14-10-16(3-2-...
# 1  InChI=1S/C28H31N5O4/c1-27(2,3)15-28(4,5)31-23-...
# 2  InChI=1S/C28H33N5O3/c1-27(2,3)16-28(4,5)31-24-...
# 3  InChI=1S/C24H23N5O4/c1-24(2,3)27-20-19(25-17-6...
# 4  InChI=1S/C24H25N5O3/c1-24(2,3)27-21-20(25-18-6...
#
#                    StdInChIKey Pharmacophore              Core ResearchStage  \
# 0  JGWFFKIYBDZDFI-FIBGUPNXSA-N   Glutarimide  LenalidomideType     Discovery
# 1  CGKKMJUNHRRYMQ-UHFFFAOYSA-N   Glutarimide   ThalidomideType     Discovery
# 2  URPATGFIHKJSDH-UHFFFAOYSA-N   Glutarimide  LenalidomideType     Discovery
# 3  IEPVLXVJCUHDAW-UHFFFAOYSA-N   Glutarimide   ThalidomideType     Discovery
# 4  IFLAYQIAAFCPNM-UHFFFAOYSA-N   Glutarimide  LenalidomideType     Discovery
#
#    TherapeuticUsage  ...  Rings  AliphaticRings  AromaticRings  \
# 0               NaN  ...      5               2              3
# 1               NaN  ...      5               2              3
# 2               NaN  ...      5               2              3
# 3               NaN  ...      5               2              3
# 4               NaN  ...      5               2              3
#
#    AliphaticHeteroRings AromaticHeteroRings HeavyAtoms  HeteroAtoms  \
# 0                     2                   0         33            8
# 1                     2                   2         37            9
# 2                     2                   2         36            8
# 3                     2                   2         33            9
# 4                     2                   2         32            8
#
#   SpiroAtoms BridgeheadAtoms                           DOI
# 0          0               0  10.1021/acs.jmedchem.3c01736
# 1          0               0          10.1021/jacs.4c06127
# 2          0               0          10.1021/jacs.4c06127
# 3          0               0          10.1021/jacs.4c06127
# 4          0               0          10.1021/jacs.4c06127
#
# [5 rows x 53 columns]

# %%
# if the PMC searches aren't yielding enough results, just go by DOI
uniqueDOIs = df['DOI'].drop_duplicates()
uniqueDOIs.to_csv('dedup_DOI-molgluedb.csv', index=False)

# %% [markdown]
# [PubMed Central ID Converter API](https://pmc.ncbi.nlm.nih.gov/tools/id-converter-api/)

# %%
dois = ",".join(uniqueDOIs)
print(dois)
print(dois.count(","))
# Out:
# 10.1021/acs.jmedchem.3c01736,10.1021/jacs.4c06127,10.1101/2024.10.01.616159,10.1021/acs.jmedchem.4c02415,10.1021/jacsau.4c00762,10.1038/s41467-024-44698-1,10.1021/acsmedchemlett.4c00250,10.1186/s13045-024-01592-z,10.26508/lsa.202000804,10.1021/acs.jmedchem.1c01832,10.1016/j.ccell.2023.02.010,10.1016/j.bmcl.2025.130193,10.1038/s41467-023-40385-9,10.1002/cbic.202300351,10.1038/nature14610,10.1021/acsmedchemlett.4c00297,10.1007/s00109-020-01943-6,10.1016/j.bmcl.2025.130263
# 17

# %%
# Required parameters
url = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/"

params = {
    'tool': 'gamma',
    'email': Entrez.email,
    'ids': dois,
    'format': 'json'  # or 'xml'
}

# %%
def process_record(record):
  if record.get('status') == 'error':
    # raise RuntimeError(record.get('errmsg'))
    return " ", record.get("doi")

  return record.get("pmcid"), record.get("doi")

# %%
# Make the request
try:
    response = requests.get(url, params=params, timeout=10)
    
    # Check if request was successful
    if response.status_code == 200:
        data = response.json()
        print("Success!")
        print(f"Status: {data.get('status', 'unknown')}")          
        print(f"Response: {data}")
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        
except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
# Out:
# Success!
# Status: ok
# Response: {'status': 'ok', 'response-date': '2026-01-25 21:01:02', 'request': {'warnings': [], 'format': 'json', 'ids': ['10.1021/acs.jmedchem.3c01736', '10.1021/jacs.4c06127', '10.1101/2024.10.01.616159', '10.1021/acs.jmedchem.4c02415', '10.1021/jacsau.4c00762', '10.1038/s41467-024-44698-1', '10.1021/acsmedchemlett.4c00250', '10.1186/s13045-024-01592-z', '10.26508/lsa.202000804', '10.1021/acs.jmedchem.1c01832', '10.1016/j.ccell.2023.02.010', '10.1016/j.bmcl.2025.130193', '10.1038/s41467-023-40385-9', '10.1002/cbic.202300351', '10.1038/nature14610', '10.1021/acsmedchemlett.4c00297', '10.1007/s00109-020-01943-6', '10.1016/j.bmcl.2025.130263'], 'email': 'tjyang2005@gmail.com', 'tool': 'gamma', 'echo': 'tool=gamma&email=tjyang2005%40gmail.com&ids=10.1021%2Facs.jmedchem.3c01736%2C10.1021%2Fjacs.4c06127%2C10.1101%2F2024.10.01.616159%2C10.1021%2Facs.jmedchem.4c02415%2C10.1021%2Fjacsau.4c00762%2C10.1038%2Fs41467-024-44698-1%2C10.1021%2Facsmedchemlett.4c00250%2C10.1186%2Fs13045-024-01592-z%2C10.26508%2Flsa.202000804%2C10.1021%2Facs.jmedchem.1c01832%2C10.1016%2Fj.ccell.2023.02.010%2C10.
  print(i, record)
  pmcid, doi = process_record(record)
  assert doi == id, f"{doi} != {id}"
  pmcids.append(pmcid)
# Out:
# 0 {'doi': '10.1021/acs.jmedchem.3c01736', 'pmcid': 'PMC11302056', 'pmid': 38085607, 'requested-id': '10.1021/acs.jmedchem.3c01736'}
# 1 {'doi': '10.1021/jacs.4c06127', 'pmcid': 'PMC11800961', 'pmid': 39499896, 'requested-id': '10.1021/jacs.4c06127'}
# 2 {'doi': '10.1101/2024.10.01.616159', 'requested-id': '10.1101/2024.10.01.616159', 'status': 'error', 'errmsg': 'Identifier not found in PMC'}
# 3 {'doi': '10.1021/acs.jmedchem.4c02415', 'requested-id': '10.1021/acs.jmedchem.4c02415', 'status': 'error', 'errmsg': 'Identifier not found in PMC'}
# 4 {'doi': '10.1021/jacsau.4c00762', 'pmcid': 'PMC11600170', 'pmid': 39610741, 'requested-id': '10.1021/jacsau.4c00762'}
# 5 {'doi': '10.1038/s41467-024-44698-1', 'pmcid': 'PMC10791743', 'pmid': 38228616, 'requested-id': '10.1038/s41467-024-44698-1'}
# 6 {'doi': '10.1021/acsmedchemlett.4c00250', 'pmcid': 'PMC11472389', 'pmid': 39411539, 'requested-id': '10.1021/acsmedchemlett.4c00250'}
# 7 {'doi': '10.1186/s13045-024-01592-z', 'pmcid': 'PMC11367868', 'pmid': 39218923, 'requested-id': '10.1186/s13045-024-01592-z'}
# 8 {'doi': '10.26508/lsa.202000804', 'pmcid': 'PMC7768194', 'pmid': 33361334, 'requested-id': '10.26508/lsa.202000804'}
# 9 {'doi': '10.1021/acs.jmedchem.1c01832', 'pmcid': 'PMC10297557', 'pmid': 34965125, 'requested-id': '10.1021/acs.jmedchem.1c01832'}
# 10 {'doi': '10.1016/j.ccell.2023.02.010', 'pmcid': 'PMC10466730', 'pmid': 36898380, 'requested-id': '10.1016/j.ccell.2023.02.010'}
# 11 {'doi': '10.1016/j.bmcl.2025.130193', 'requested-id': '10.1016/j.bmcl.2025.130193', 'status': 'error', 'errmsg': 'Identifier not found in PMC'}
# 12 {'doi': '10.1038/s41467-023-40385-9', 'pmcid': 'PMC10439208', 'pmid': 37596276, 'requested-id': '10.1038/s41467-023-40385-9'}
# 13 {'doi': '10.1002/cbic.202300351', 'requested-id': '10.1002/cbic.202300351', 'status': 'error', 'errmsg': 'Identifier not found in PMC'}
# 14 {'doi': '10.1038/nature14610', 'pmcid': 'PMC4853910', 'pmid': 26131937, 'requested-id': '10.1038/nature14610'}
# 15 {'doi': '10.1021/acsmedchemlett.4c00297', 'pmcid': 'PMC11403733', 'pmid': 39291008, 'requested-id': '10.1021/acsmedchemlett.4c00297'}
# 16 {'doi': '10.1007/s00109-020-01943-6', 'pmcid': 'PMC10838157', 'pmid': 32632752, 'requested-id': '10.1007/s00109-020-01943-6'}
# 17 {'doi': '10.1016/j.bmcl.2025.130263', 'requested-id': '10.1016/j.bmcl.2025.130263', 'status': 'error', 'errmsg': 'Identifier not found in PMC'}

# %%
df = pd.DataFrame({
  "DOI": uniqueDOIs,
  "PMCID": pmcids
})
df = df[df['PMCID'] != " "]
df.to_csv("ground_truth-molgluedb.csv", index=False)
